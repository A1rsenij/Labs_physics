# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
# %matplotlib qt

# %%
D = 1 / np.array([6760, 3200, 1120])
d = np.array([17.3, 25.0, 48.2])

k = np.polyfit(D, d, 1)
dp = np.polyval(k, D)

fig, ax = plt.subplots(figsize=(10, 6), dpi=100)

ax.scatter(D, d, label='d', color="orange", marker='.')
ax.plot(D, dp, label='$d = f(1/D)$')

ax.legend(loc='upper left', fontsize=10)

ax.grid(which="major", linewidth=0.5)
ax.grid(which="minor", linestyle='--', linewidth=0.25)
plt.minorticks_on()

ax.axis([0, 0.001, 10, 50])

ax.set_title(r"График зависимости $d = f(1/D)$", loc='center', fontsize=15)
ax.set_xlabel(r"$1/D,\; мкм^{-1}$", loc='center', fontsize=10)
ax.set_ylabel(r"$d,\; мкм$", loc='center', fontsize=10)

plt.show()

fig.savefig("4.3.3_1.png", dpi=500)
